# %% [markdown]
# ## Podmíněný výběr

# %% [markdown]
# Vyzkoušíme si jeden z hlavních nástrojů zpracování dat, a to je psaní dotazů.
#
# Logika psaní dotazů je v různých prostředích stejná, liší se pouze to, jak ji provádíme.

# %%
import pandas as pd

# %%
url_food_nutrient = "https://kodim.cz/cms/assets/czechitas/python-data-1/python-pro-data-1/podmineny-vyber/podmineny-vyber/food_nutrient.csv"
food_nutrient = pd.read_csv(url_food_nutrient)
food_nutrient.head()
# Out:
#     fdc_id  nutrient_id  amount  data_points  derivation_id  min  max  median  \
# 0  1106032         1257     NaN          NaN           71.0  NaN  NaN     NaN
# 1  1107191         1257     NaN          NaN           70.0  NaN  NaN     NaN
# 2  1107295         1257     NaN          NaN           70.0  NaN  NaN     NaN
# 3  1107475         1257     NaN          NaN           70.0  NaN  NaN     NaN
# 4  1107528         1257     0.0          NaN           70.0  NaN  NaN     NaN
#
#    loq  footnote  min_year_acquired                      name unit_name
# 0  NaN       NaN                NaN  Fatty acids, total trans         G
# 1  NaN       NaN                NaN  Fatty acids, total trans         G
# 2  NaN       NaN                NaN  Fatty acids, total trans         G
# 3  NaN       NaN                NaN  Fatty acids, total trans         G
# 4  NaN       NaN                NaN  Fatty acids, total trans         G

# %% [markdown]
#  Stručný popis sloupců tabulky.
#
# - `id`: Identifikační číslo záznamu.
# - `fdc_id`: Identifikační číslo potraviny, ke které se vztahuje živina.
# - `nutrient_id`: Identifikační číslo živiny.
# - `amount`: Množství živiny v potravině.
# - `data_points`: Počet datových bodů použitých pro výpočet průměru.
# - `derivation_id`: Identifikační číslo metody, kterou byla hodnota živiny odvozena.
# - `standard_error`: Standardní chyba měření množství živiny.
# - `min`: Minimální hodnota množství živiny nalezlá v potravině.
# - `max`: Maximální hodnota množství živiny nalezlá v potravině.
# - `median`: Medián hodnot množství živiny v potravině.
# - `footnote`: Poznámka nebo dodatečné informace o živině.
# - `name`: Název živiny.
# - `unit_name`: Název jednotky, ve které se měří živina.
# - `nutrient_nbr`: Unikátní číslo identifikující živinu nebo potravinovou složku​.

# %% [markdown]
# ### Co vlastně umí série

# %%
food_nutrient["name"]
# Out:
# 0         Fatty acids, total trans
# 1         Fatty acids, total trans
# 2         Fatty acids, total trans
# 3         Fatty acids, total trans
# 4         Fatty acids, total trans
#                     ...
# 135331                   Vitamin E
# 135332                   Vitamin E
# 135333                   Vitamin E
# 135334                   Vitamin E
# 135335                   Vitamin E
# Name: name, Length: 135336, dtype: object

# %%
food_nutrient["name"].unique()
# Out:
# array(['Fatty acids, total trans', 'Fatty acids, total polyunsaturated',
#        'Cholesterol', 'Potassium, K', 'Energy', 'Iron, Fe',
#        'Vitamin C, total ascorbic acid', 'Fatty acids, total saturated',
#        'Calcium, Ca', 'Fatty acids, total monounsaturated', 'Sodium, Na',
#        'Vitamin A, IU', 'Sugars, total including NLEA',
#        'Fiber, total dietary', 'Vitamin D (D2 + D3), International Units',
#        'Carbohydrate, by difference', 'Total lipid (fat)', 'Protein',
#        'Folic acid', 'Folate, DFE', 'Riboflavin', 'Thiamin',
#        'Vitamin B-12', 'Vitamin B-6', 'Phosphorus, P', 'Manganese, Mn',
#        'Magnesium, Mg', 'Niacin', 'Sugars, added', 'Folate, total',
#        'Selenium, Se', 'Pantothenic acid', 'Iodine, I', 'Zinc, Zn',
#        'Vitamin E', 'Fiber, soluble', 'Fiber, insoluble',
#        'Total sugar alcohols', 'Vitamin K (phylloquinone)', 'Copper, Cu',
#        'Carbohydrate, other', 'Molybdenum, Mo', 'Chromium, Cr', 'Biotin',
#        'Inulin', 'Vitamin E (alpha-tocopherol)', 'Xylitol',
#        'Choline, total', 'Chlorine, Cl', 'Lactose',
#        'Vitamin D3 (cholecalciferol)', 'Water', 'Ash', 'Vitamin A, RAE',
#        'Retinol', 'MUFA 18:1', 'SFA 16:0', 'PUFA 18:3', 'PUFA 18:2',
#        'Carotene, alpha', 'Starch', 'Tocotrienol, alpha', 'MUFA 15:1',
#        'Tryptophan', 'Carotene, beta', 'PUFA 22:5 n-3 (DPA)', 'SFA 18:0',
#        'Tocotrienol, beta', 'MUFA 22:1', 'SFA 22:0', 'PUFA 18:4',
#        'Tocotrienol, delta', 'Maltose', 'Tocopherol, delta', 'Methionine',
#        'PUFA 20:3', 'Glutamic acid', 'PUFA 18:3 n-6 c,c,c', 'Fructose',
#        'Glucose', 'Tocopherol, beta', 'Vitamin E, added', 'Sucrose',
#        'Aspartic acid', 'Phenylalanine', 'Cystine', 'Glycine',
#        'Galactose', 'Theobromine', 'SFA 4:0', 'Valine', 'MUFA 14:1',
#        'Threonine', 'PUFA 22:6 n-3 (DHA)', 'SFA 14:0', 'Alcohol, ethyl',
#        'PUFA 20:2 n-6 c,c', 'Tocopherol, gamma', 'SFA 6:0', 'SFA 8:0',
#        'SFA 10:0', 'Histidine', 'Lycopene', 'Arginine', 'Folate, food',
#        'SFA 20:0', 'Vitamin K (Dihydrophylloquinone)', 'MUFA 17:1',
#        'Lysine', 'SFA 17:0', 'Tocotrienol, gamma', 'Serine', 'Caffeine',
#        'Proline', 'MUFA 20:1', 'Tyrosine', 'Cryptoxanthin, beta',
#        'SFA 12:0', 'Isoleucine', 'SFA 15:0', 'MUFA 16:1',
#        'Lutein + zeaxanthin', 'Leucine', 'Vitamin B-12, added', 'Alanine',
#        'PUFA 20:5 n-3 (EPA)', 'PUFA 20:4', 'Vitamin D (D2 + D3)',
#        'Betaine', 'Vitamin K (Menaquinone-4)', 'MUFA 16:1 c', 'PUFA 21:5',
#        'MUFA 24:1 c', 'SFA 24:0', 'PUFA 22:4', 'Hydroxyproline',
#        'PUFA 18:3 n-3 c,c,c (ALA)', 'TFA 18:2 t,t',
#        'Fatty acids, total trans-polyenoic',
#        'Fatty acids, total trans-monoenoic', 'TFA 18:1 t',
#        'PUFA 18:2 n-6 c,c', 'PUFA 18:2 CLAs', 'MUFA 22:1 c',
#        'TFA 18:2 t not further defined', 'PUFA 20:3 n-3', 'TFA 22:1 t',
#        'MUFA 18:1 c', 'PUFA 20:3 n-6', 'TFA 16:1 t', 'Fluoride, F',
#        'PUFA 18:3i', 'Stigmasterol', 'Beta-sitosterol', 'Campesterol',
#        'PUFA 18:2 i', 'SFA 13:0', 'Phytosterols',
#        'Vitamin D2 (ergocalciferol)', 'Nitrogen', 'SFA 11:0',
#        'PUFA 20:3 n-9', 'MUFA 20:1 c', 'PUFA 22:2', 'MUFA 22:1 n-9',
#        'TFA 18:3 t', 'MUFA 14:1 c', '25-hydroxycholecalciferol',
#        'SFA 21:0', 'SFA 9:0', 'SFA 7:0', 'MUFA 22:1 n-11', 'PUFA 22:3',
#        'SFA 23:0', 'TFA 14:1 t', 'TFA 20:1 t', 'MUFA 12:1', 'SFA 5:0',
#        'Cysteine', 'Zeaxanthin', 'trans-beta-Carotene', 'trans-Lycopene',
#        'Lutein', 'cis-beta-Carotene', 'cis-Lycopene',
#        'Cryptoxanthin, alpha', 'cis-Lutein/Zeaxanthin',
#        'Total fat (NLEA)', 'Sugars, Total', 'Sulfur, S', 'Cobalt, Co',
#        'Boron, B', 'Nickel, Ni', 'Vitamin E (label entry primarily)',
#        'Epigallocatechin-3-gallate', 'Beta-sitostanol',
#        'Delta-5-avenasterol', 'Stigmastadiene', 'Delta-7-Stigmastenol',
#        'Beta-glucan', 'Ergosterol', ' Ergosta-5,7-dienol', 'Oxalic acid',
#        'High Molecular Weight Dietary Fiber (HMWDF)', 'Vitamin A'],
#       dtype=object)

# %%
food_nutrient["name"].value_counts()
# Out:
# name
# Protein                        9553
# Sodium, Na                     9499
# Energy                         9473
# Total lipid (fat)              9413
# Carbohydrate, by difference    9357
#                                ...
# SFA 5:0                           1
# MUFA 12:1                         1
# SFA 21:0                          1
# SFA 23:0                          1
# TFA 18:2 t,t                      1
# Name: count, Length: 205, dtype: int64

# %% [markdown]
# ### Podmíněný výběr

# %% [markdown]
# Uvažujme, že nám jde o obsah hořčíku (Magnesium), protože naším úkolem je doporučit potraviny lidem s nedostatkem hořčíku.

# %% [markdown]
# Při použití operátorů pro porovnávání vždy získáme hodnotu typu `bool`.

# %%
food_nutrient["name"] == "Magnesium, Mg"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 135331    False
# 135332    False
# 135333    False
# 135334    False
# 135335    False
# Name: name, Length: 135336, dtype: bool

# %% [markdown]
# `pandas` teď jednoduše udělají to, že vypíšou ty řádky řádky, kde má náš polotovar hodnotu `True` a ty, které mají hodnotu `False`, před námi skryjí.

# %%
magnesium = food_nutrient[food_nutrient["name"] == "Magnesium, Mg"]
magnesium.head()
# Out:
#          fdc_id  nutrient_id  amount  data_points  derivation_id  min  max  \
# 125766  1108349         1090   147.0          NaN           70.0  NaN  NaN
# 125767  1109796         1090   156.0          NaN           75.0  NaN  NaN
# 125768  1114461         1090   107.0          NaN           70.0  NaN  NaN
# 125769  1114961         1090   267.0          NaN           75.0  NaN  NaN
# 125770  1118500         1090   158.0          NaN           70.0  NaN  NaN
#
#         median  loq  footnote  min_year_acquired           name unit_name
# 125766     NaN  NaN       NaN                NaN  Magnesium, Mg        MG
# 125767     NaN  NaN       NaN                NaN  Magnesium, Mg        MG
# 125768     NaN  NaN       NaN                NaN  Magnesium, Mg        MG
# 125769     NaN  NaN       NaN                NaN  Magnesium, Mg        MG
# 125770     NaN  NaN       NaN                NaN  Magnesium, Mg        MG

# %%
food_nutrient[food_nutrient["unit_name"].str.lower().isin(["g", "mg", "kcal"])]#["unit_name"].unique()
# Out:
#          fdc_id  nutrient_id  amount  data_points  derivation_id  min  max  \
# 0       1106032         1257     NaN          NaN           71.0  NaN  NaN
# 1       1107191         1257     NaN          NaN           70.0  NaN  NaN
# 2       1107295         1257     NaN          NaN           70.0  NaN  NaN
# 3       1107475         1257     NaN          NaN           70.0  NaN  NaN
# 4       1107528         1257     0.0          NaN           70.0  NaN  NaN
# ...         ...          ...     ...          ...            ...  ...  ...
# 135331  2614074         2068     0.0          NaN           71.0  NaN  NaN
# 135332  2622536         2068     2.0          NaN           70.0  NaN  NaN
# 135333  2622742         2068    13.0          NaN           70.0  NaN  NaN
# 135334  2627542         2068     2.0          NaN           75.0  NaN  NaN
# 135335  2654454         2068    25.0          NaN           70.0  NaN  NaN
#
#         median  loq  footnote  min_year_acquired                      name  \
# 0          NaN  NaN       NaN                NaN  Fatty acids, total trans
# 1          NaN  NaN       NaN                NaN  Fatty acids, total trans
# 2          NaN  NaN       NaN                NaN  Fatty acids, total trans
# 3          NaN  NaN       NaN                NaN  Fatty acids, total trans
# 4          NaN  NaN       NaN                NaN  Fatty acids, total trans
# ...        ...  ...       ...                ...                       ...
# 135331     NaN  NaN       NaN                NaN                 Vitamin E
# 135332     NaN  NaN       NaN                NaN                 Vitamin E
# 135333     NaN  NaN       NaN                NaN                 Vitamin E
# 135334     NaN  NaN       NaN                NaN                 Vitamin E
# 135335     NaN  NaN       NaN                NaN                 Vitamin E
#
#        unit_name
# 0              G
# 1              G
# 2              G
# 3              G
# 4              G
# ...          ...
# 135331        MG
# 135332        MG
# 135333        MG
# 135334        MG
# 135335        MG
#
# [125613 rows x 13 columns]

# %% [markdown]
# ### Popisná statistika

# %%
magnesium["amount"].describe()
# Out:
# count     394.000000
# mean      102.079797
# std       210.755384
# min         0.000000
# 25%        13.000000
# 50%        43.000000
# 75%       124.250000
# max      2941.000000
# Name: amount, dtype: float64

# %% [markdown]
# Naším úkolem je vybrat potraviny, které mají vyšší množství hořčíku. K tomu opět využijeme dotaz.
#
# Uvažujeme, že nás zajímají potraviny, které mají více než 100 gramů hořčíku.

# %%
magnesium_limit = magnesium[magnesium["amount"] > 100]
magnesium_limit
# Out:
#          fdc_id  nutrient_id  amount  data_points  derivation_id  min  max  \
# 125766  1108349         1090   147.0          NaN           70.0  NaN  NaN
# 125767  1109796         1090   156.0          NaN           75.0  NaN  NaN
# 125768  1114461         1090   107.0          NaN           70.0  NaN  NaN
# 125769  1114961         1090   267.0          NaN           75.0  NaN  NaN
# 125770  1118500         1090   158.0          NaN           70.0  NaN  NaN
# ...         ...          ...     ...          ...            ...  ...  ...
# 126141  2550641         1090   218.0          NaN           70.0  NaN  NaN
# 126147  2558685         1090   133.0          NaN           78.0  NaN  NaN
# 126148  2592707         1090   207.0          NaN           70.0  NaN  NaN
# 126154  2627542         1090   118.0          NaN           75.0  NaN  NaN
# 126157  2654454         1090   257.0          NaN           70.0  NaN  NaN
#
#         median  loq  footnote  min_year_acquired           name unit_name
# 125766     NaN  NaN       NaN                NaN  Magnesium, Mg        MG
# 125767     NaN  NaN       NaN                NaN  Magnesium, Mg        MG
# 125768     NaN  NaN       NaN                NaN  Magnesium, Mg        MG
# 125769     NaN  NaN       NaN                NaN  Magnesium, Mg        MG
# 125770     NaN  NaN       NaN                NaN  Magnesium, Mg        MG
# ...        ...  ...       ...                ...            ...       ...
# 126141     NaN  NaN       NaN                NaN  Magnesium, Mg        MG
# 126147     NaN  NaN       NaN                NaN  Magnesium, Mg        MG
# 126148     NaN  NaN       NaN                NaN  Magnesium, Mg        MG
# 126154     NaN  NaN       NaN                NaN  Magnesium, Mg        MG
# 126157     NaN  NaN       NaN                NaN  Magnesium, Mg        MG
#
# [117 rows x 13 columns]

# %% [markdown]
# ### Spojení více podmínek
#
# Pokud chceme, aby musely být splněny obě podmínky, vložíme mezi ně symbol `&`.
#
# Pokud chceme, aby stačilo splnění jedné podmínky, použijeme symbol `|`.

# %% [markdown]
# Naším úkolem bude vybrat potraviny, které mají mezi 30 a 500 mg vápníku.

# %%
calcium = food_nutrient[food_nutrient["name"] == "Calcium, Ca"]
calcium_limit = calcium[(calcium["amount"] > 30) & (calcium["amount"] < 500)]
calcium_limit
# Out:
#         fdc_id  nutrient_id  amount  data_points  derivation_id  min  max  \
# 51848  1107475         1087   129.0          NaN           70.0  NaN  NaN
# 51849  1107528         1087   107.0          NaN           75.0  NaN  NaN
# 51850  1108007         1087    31.0          NaN           70.0  NaN  NaN
# 51852  1108349         1087   382.0          NaN           70.0  NaN  NaN
# 51853  1108803         1087    33.0          NaN           75.0  NaN  NaN
# ...        ...          ...     ...          ...            ...  ...  ...
# 59729  2659382         1087    67.0          NaN           75.0  NaN  NaN
# 59730  2659508         1087    31.0          NaN           75.0  NaN  NaN
# 59733  2660573         1087    80.0          NaN           75.0  NaN  NaN
# 59734  2660613         1087   133.0          NaN           70.0  NaN  NaN
# 59741  2661782         1087    83.0          NaN           75.0  NaN  NaN
#
#        median  loq  footnote  min_year_acquired         name unit_name
# 51848     NaN  NaN       NaN                NaN  Calcium, Ca        MG
# 51849     NaN  NaN       NaN                NaN  Calcium, Ca        MG
# 51850     NaN  NaN       NaN                NaN  Calcium, Ca        MG
# 51852     NaN  NaN       NaN                NaN  Calcium, Ca        MG
# 51853     NaN  NaN       NaN                NaN  Calcium, Ca        MG
# ...       ...  ...       ...                ...          ...       ...
# 59729     NaN  NaN       NaN                NaN  Calcium, Ca        MG
# 59730     NaN  NaN       NaN                NaN  Calcium, Ca        MG
# 59733     NaN  NaN       NaN                NaN  Calcium, Ca        MG
# 59734     NaN  NaN       NaN                NaN  Calcium, Ca        MG
# 59741     NaN  NaN       NaN                NaN  Calcium, Ca        MG
#
# [4005 rows x 13 columns]

# %%
calcium_limit = food_nutrient[
    (food_nutrient["name"] == "Calcium, Ca")
    & (food_nutrient["amount"] > 30)
    & (food_nutrient["amount"] < 500)
]

calcium_limit
# Out:
#         fdc_id  nutrient_id  amount  data_points  derivation_id  min  max  \
# 51848  1107475         1087   129.0          NaN           70.0  NaN  NaN
# 51849  1107528         1087   107.0          NaN           75.0  NaN  NaN
# 51850  1108007         1087    31.0          NaN           70.0  NaN  NaN
# 51852  1108349         1087   382.0          NaN           70.0  NaN  NaN
# 51853  1108803         1087    33.0          NaN           75.0  NaN  NaN
# ...        ...          ...     ...          ...            ...  ...  ...
# 59729  2659382         1087    67.0          NaN           75.0  NaN  NaN
# 59730  2659508         1087    31.0          NaN           75.0  NaN  NaN
# 59733  2660573         1087    80.0          NaN           75.0  NaN  NaN
# 59734  2660613         1087   133.0          NaN           70.0  NaN  NaN
# 59741  2661782         1087    83.0          NaN           75.0  NaN  NaN
#
#        median  loq  footnote  min_year_acquired         name unit_name
# 51848     NaN  NaN       NaN                NaN  Calcium, Ca        MG
# 51849     NaN  NaN       NaN                NaN  Calcium, Ca        MG
# 51850     NaN  NaN       NaN                NaN  Calcium, Ca        MG
# 51852     NaN  NaN       NaN                NaN  Calcium, Ca        MG
# 51853     NaN  NaN       NaN                NaN  Calcium, Ca        MG
# ...       ...  ...       ...                ...          ...       ...
# 59729     NaN  NaN       NaN                NaN  Calcium, Ca        MG
# 59730     NaN  NaN       NaN                NaN  Calcium, Ca        MG
# 59733     NaN  NaN       NaN                NaN  Calcium, Ca        MG
# 59734     NaN  NaN       NaN                NaN  Calcium, Ca        MG
# 59741     NaN  NaN       NaN                NaN  Calcium, Ca        MG
#
# [4005 rows x 13 columns]

# %% [markdown]
# Pokud chceme, aby stačilo splnění jedné podmínky, použijeme symbol `|`.

# %% [markdown]
# ---
# # Cvičení

# %% [markdown]
# ## Vláknina

# %% [markdown]
# Problémem dnešních potravin je často nedostatek vlákniny.
#
# Konzumace potravin bohatých na vlákninu může být pro řadu lidí zdravotně prospěná.
#
# Vyhledej v tabulce `food_nutrient` potraviny, které obsahují alespoň 10 gramů vlákniny.
#
# Vláknina je uložená pod názvem `Fiber, total dietary`.
#
# Napiš dotaz jako jeden příkaz a využij operátor `&`.

# %%
food_nutrient[(food_nutrient["name"] == "Fiber, total dietary") & (food_nutrient["amount"] >= 10)]
# Out:
#         fdc_id  nutrient_id  amount  data_points  derivation_id  min  max  \
# 83639  1109336         1079    10.0          NaN           70.0  NaN  NaN
# 83666  1114461         1079    10.7          NaN           70.0  NaN  NaN
# 83667  1114961         1079    10.0          NaN           70.0  NaN  NaN
# 83675  1117734         1079    10.0          NaN           70.0  NaN  NaN
# 83681  1118500         1079    11.1          NaN           70.0  NaN  NaN
# ...        ...          ...     ...          ...            ...  ...  ...
# 91545  2638057         1079    15.0          NaN           70.0  NaN  NaN
# 91584  2651678         1079    39.5          NaN           70.0  NaN  NaN
# 91598  2654454         1079    10.7          NaN           70.0  NaN  NaN
# 91599  2654695         1079    11.8          NaN           70.0  NaN  NaN
# 91629  2660613         1079    10.0          NaN           70.0  NaN  NaN
#
#        median  loq  footnote  min_year_acquired                  name  \
# 83639     NaN  NaN       NaN                NaN  Fiber, total dietary
# 83666     NaN  NaN       NaN                NaN  Fiber, total dietary
# 83667     NaN  NaN       NaN                NaN  Fiber, total dietary
# 83675     NaN  NaN       NaN                NaN  Fiber, total dietary
# 83681     NaN  NaN       NaN                NaN  Fiber, total dietary
# ...       ...  ...       ...                ...                   ...
# 91545     NaN  NaN       NaN                NaN  Fiber, total dietary
# 91584     NaN  NaN       NaN                NaN  Fiber, total dietary
# 91598     NaN  NaN       NaN                NaN  Fiber, total dietary
# 91599     NaN  NaN       NaN                NaN  Fiber, total dietary
# 91629     NaN  NaN       NaN                NaN  Fiber, total dietary
#
#       unit_name
# 83639         G
# 83666         G
# 83667         G
# 83675         G
# 83681         G
# ...         ...
# 91545         G
# 91584         G
# 91598         G
# 91599         G
# 91629         G
#
# [554 rows x 13 columns]

# %% [markdown]
# # Hlášení chyb

# %% [markdown]
# V datech se bohužel můžou vyskytnout i chyby.
#
#  V případě výživných látek jsou uváděné hodnoty vždy přepočtené na 100 gramů potraviny.
#
#  Chybou by tedy například bylo, pokud by bylo nějaké výživné látky v potravině více než 100 gramů, tj. výživné látky by bylo více než samotné potraviny.
#
#  Podobně to platí i pro miligramy. Více než 100 000 miligramů výživné látky též nedává smysl (1 gram = 1 000 miligramů).

# %% [markdown]
# Vyhledej všechny řádky, kde jsou hodnoty v miligramech (ve sloupci `unit_name` je hodnota `MG`) a množství látky (sloupec `amount`) má větší hodnotu než 100 000.

# %%
errors = food_nutrient[(food_nutrient["unit_name"] == "MG") & (food_nutrient["amount"] > 100_000)]

# %% [markdown]
# Ulož tato data do tabulky `error_report.csv`. K tomu využij metodu `.to_csv()`, které zadáš jako parametr název tabulky.
#
# Níže je příklad jejího použití.
#
# ```
# tabulky.to_csv("nazev_souboru.csv")
# ```
#
# Takto vytvořenou tabulku bychom mohli poslat poskytovateli dat a požádat ho o opravu.

# %%
errors.to_csv("error_reports.csv")

# %% [markdown]
# ## Česká jména

# %% [markdown]
# Použij soubor `jmena.csv` se jmény a načti ho tak, aby Pandas vyrobil číselný index.

# %%
url = "https://kodim.cz/cms/assets/czechitas/python-data-1/python-pro-data-1/podmineny-vyber/podmineny-vyber/ceska-jmena/jmena.csv"
jmena = pd.read_csv(url)

# %% [markdown]
# Proveď následující dotazy:

# %% [markdown]
# Vypiš všechny řádky se jmény, jejichž nositelé mají průměrný věk vyšší než 60.

# %%
jmena[jmena["prumerny_vek"] > 60]
# Out:
#         jmeno  cetnost  prumerny_vek pohlavi      puvod
# 4       Marie   260526            65       ž  hebrejský
# 23       Věra   107388            63       ž  slovanský
# 30  Jaroslava    84556            63       ž  slovanský
# 38    Ludmila    72750            65       ž  slovanský
# 40     Zdeňka    69060            61       ž  slovanský
# 50    Jarmila    59666            65       ž  slovanský
# 53     Jiřina    55366            64       ž      řecký
# 64     Vlasta    41736            68       ž  slovanský
# 68     Božena    39851            72       ž  slovanský
# 70     Libuše    39269            66       ž  slovanský
# 71      Marta    38897            63       ž  aramejský
# 91     Růžena    28952            69       ž  slovanský
# 99     Zdenka    25416            68       ž  slovanský

# %% [markdown]
# Vypiš pouze jména z těch řádků, kde četnost je mezi 80 000 a 100 000.

# %%
jmena[(jmena["cetnost"] >= 80_000) & (jmena["cetnost"] <= 100_000)]
# Out:
#         jmeno  cetnost  prumerny_vek pohlavi      puvod
# 29   Veronika    88854            25       ž      řecký
# 30  Jaroslava    84556            63       ž  slovanský
# 31   Vladimír    83762            56       m  slovanský
# 32     Tereza    83692            18       ž      řecký
# 33    Martina    81312            36       ž   latinský

# %% [markdown]
# Vypiš jména a četnost pro jména se slovanským nebo hebrejským původem. Kolik takových jmen je?
#
# Pro poslední úkol můžeš využít operátor |. Alternativně si můžeš vyzkoušet metodu .isin(), která zápis zkrátí.
#
# Jako parametr vkládáme seznam hodnot, které vyhovují podmínce.
#
# Níže je příklad použití metody. Z tabulky tabulka chceme vybrat řádky, které ve sloupci sloupec mají hodnotu hodnota_1 nebo hodnota_2.
#
# Pokud jsi vytvořil(a) i verzi s operátorem |, můžeš obě verze porovnat a rozhodnout se, která verze se ti líbí více.
#
# `tabulka = tabulka[tabulka["sloupec"].isin(["hodnota_1", "hodnota_2"])]`

# %%
jmena[(jmena["puvod"] == "slovanský") | (jmena["puvod"] == "hebrejský")]
# jmena[jmena["puvod"].isin(["slovanský", "hebrejský"])]
# Out:
#         jmeno  cetnost  prumerny_vek pohlavi      puvod
# 1         Jan   293938            40       m  hebrejský
# 3        Jana   264944            50       ž  hebrejský
# 4       Marie   260526            65       ž  hebrejský
# 5       Josef   211317            57       m  hebrejský
# 9    Jaroslav   172785            55       m  slovanský
# 10        Eva   152463            53       ž  hebrejský
# 11   Miroslav   147753            52       m  slovanský
# 12       Hana   145901            51       ž  hebrejský
# 13       Anna   134819            51       ž  hebrejský
# 14     Zdeněk   126094            54       m  slovanský
# 15     Václav   123927            51       m  slovanský
# 16     Michal   123324            32       m  hebrejský
# 21      Jakub   108013            19       m  hebrejský
# 22      Milan   107458            51       m  slovanský
# 23       Věra   107388            63       ž  slovanský
# 24      Alena   105093            55       ž  hebrejský
# 28      David   101311            25       m  hebrejský
# 30  Jaroslava    84556            63       ž  slovanský
# 31   Vladimír    83762            56       m  slovanský
# 34   Michaela    78823            28       ž  hebrejský
# 35      Jitka    78187            51       ž  hebrejský
# 38    Ludmila    72750            65       ž  slovanský
# 39   Ladislav    69797            55       m  slovanský
# 40     Zdeňka    69060            61       ž  slovanský
# 41      Ivana    68917            49       ž  slovanský
# 45  Stanislav    61889            54       m  slovanský
# 46     Eliška    61517            24       ž  hebrejský
# 47     Zuzana    61382            34       ž  hebrejský
# 48     Daniel    60935            23       m  hebrejský
# 50    Jarmila    59666            65       ž  slovanský
# 51      Radek    58589            36       m  slovanský
# 56    Vojtěch    52802            22       m  slovanský
# 58       Dana    50781            51       ž  hebrejský
# 61       Adam    47837            14       m  hebrejský
# 64     Vlasta    41736            68       ž  slovanský
# 66  Miroslava    41151            54       ž  slovanský
# 68     Božena    39851            72       ž  slovanský
# 70     Libuše    39269            66       ž  slovanský
# 72      Matěj    38519            13       m  hebrejský
# 73      Šárka    38339            37       ž  slovanský
# 82   Miloslav    32769            60       m  slovanský
# 84   Gabriela    31175            33       ž  hebrejský
# 85    Jaromír    30984            55       m  slovanský
# 89      Aneta    29840            17       ž  hebrejský
# 90     Simona    29618            30       ž  hebrejský
# 91     Růžena    28952            69       ž  slovanský
# 92      Radka    26939            38       ž  slovanský
# 93    Daniela    26536            38       ž  hebrejský
# 96  Vlastimil    26014            54       m  slovanský
# 97        Iva    26003            46       ž  slovanský
# 98      Miloš    25509            53       m  slovanský
# 99     Zdenka    25416            68       ž  slovanský

# %% [markdown]
# ## Dvě kritéria

# %% [markdown]
# Připravujeme seznam potravin pro účely lékařského výzkumu, který se bude zabývat kardiovaskulárním systémem. Chceme vybrat potraviny, které splňují dvě kritéria:
#
# - nízký obsah nasycených mastných kyselin (`Fatty acids, total saturated`, uvažuj méně než 1 gram),
# - vysoký obsah vlákniny (`Fiber, total dietary`, uvažuj více než 5 gramů).
#
# Zatímco nasycené mastné kyseliny jsou považovány za spíše škodlivé pro kardiovaskulární systém, vláknina je považována spíše za prospěšnou.
#
# Nejprve je potřeba napsat dotaz, který potraviny vybere. Dotaz je poměrně složitý, ale později si v rámci kurzu ukážeme, jak takovou úlohu vyřešit jednodušeji. Je potřeba použít operátor & i | a závorky, pomocí kterých řídíme, které podmínky se vyhodnocují spolu. Níže jsou rozepsané podmínky, které budeme potřebovat:
#
# - Ve sloupci "name" musí být hodnota "Fatty acids, total saturated" a současně ve sloupci "amount" hodnota menší než 1. Mezi tyto podmínky vložíme operátor &, protože musí být splněné obě.
# - Ve sloupci "name" musí být hodnota "Fiber, total dietary" a současně ve sloupci "amount" hodnota vetší než 4. Mezi tyto podmínky vložíme operátor &, protože musí být splněné obě.
#
# Protože obě výživné látky jsou na samostatném řádku, musíme mezi obě podmínky dát operátor |. Pokud nějaká potraviny splňuje obě podmínky, bude tedy ve výsledné tabulce dvakrát. Pokud splňuje pouze jednou z podmínek, bude ve výsledné tabulce pouze jednou. Počet výskytů potraviny ve výsledné tabulce můžeme ověřit pomocí metodu values_count().
#
# U kombinace operátorů & a | je vhodné uvědomit si, v jaké prioritě by měly být používány. Ač to zní složitě, je to pojem, který už známe z úvodního kurzu z příkladu, kde jsme používali násobení a sčítání v jednom příkladu. Pro operátory & a | platí, že operátor & máš vyšší prioritu než |. To nám vyhovuje, protože my chceme nejprve vyhodnotit podmínky s operátorem & a poté spojit výsledky s využitím opretáro |.
#
# Níže je tedy struktura, kterou je potřeba upravit, aby řešila popsané podmínky.
#
# ```
# food_nutrient_filtered = food_nutrient[(ve sloupci "name" je hodnota "Fatty acids, total saturated") & (ve sloupci "amount" je hodnota menší než 1) | (ve sloupci "name" je hodnota "Fiber, total dietary") & (ve sloupci "amount" je hodnota větší než 4)]
# ```
#
# Pokud se úvaze o priotách chceš vyhnout, je možné to vyřešit přidanými závorkami. Tyto závorky nijak neovlivňují, jak Python příkaz vyhodnotí, ale můžou zlepšit čistelnost a pochopitelnost příkazu pro člověka.
#
# ```
# food_nutrient_filtered = food_nutrient[((ve sloupci "name" je hodnota "Fatty acids, total saturated") & (ve sloupci "amount" je hodnota menší než 1)) | ((ve sloupci "name" je hodnota "Fiber, total dietary") & (ve sloupci "amount" je hodnota větší než 4))]
# ```

# %%
food_nutrient_filtered = food_nutrient[((food_nutrient["name"] == "Fatty acids, total saturated") & (food_nutrient["amount"] < 1)) 
    | ((food_nutrient["name"] == "Fiber, total dietary") & (food_nutrient["amount"] > 5))]

food_nutrient_filtered = food_nutrient[(food_nutrient["name"] == "Fatty acids, total saturated") 
                                      & (food_nutrient["amount"] < 1) 
                                      | (food_nutrient["name"] == "Fiber, total dietary") 
                                      & (food_nutrient["amount"] > 4)]

food_nutrient_filtered["name"].value_counts()
# Out:
# name
# Fatty acids, total saturated    3405
# Fiber, total dietary            1682
# Name: count, dtype: int64
